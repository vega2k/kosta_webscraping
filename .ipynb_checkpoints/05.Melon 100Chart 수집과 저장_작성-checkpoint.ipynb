# %% [markdown]
# ### Melon 100 챠트 스크래핑
# 1. 100곡의 노래의 제목과 ID 추출 (정규표현식)
# 2. 노래의 ID로 상세페이지를 100번 요청해서 상세정보를 추출
# 3. Json file에 저장
# 4. json file을 DataFrame 객체로 생성해서 표데이터 만들기
# 5. 표데이터를 DB에 저장하기

# %%
import requests
from bs4 import BeautifulSoup
import re

url = 'https://www.melon.com/chart/index.htm'
# 요청헤더 
req_header = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36'
}
res = requests.get(url, headers=req_header)
print(res.status_code)

if res.ok:
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    # <div id="tb_list"> 
    print(len(soup.select('div#tb_list'))) #1
    # <div id="tb_list">  하위의 tr 선택
    print(len(soup.select('div#tb_list tr'))) #101
    # <div id="tb_list">  하위의 tr 하위의 <div class="wrap_song_info">
    print(len(soup.select('div#tb_list tr div.wrap_song_info'))) #200
    # <div id="tb_list">  하위의 tr 하위의 <div class="wrap_song_info"> 하위의 <a href="playSong">
    print(len(soup.select("div#tb_list tr div.wrap_song_info a[href*='playSong']"))) #100
    
    song_atag = soup.select("div#tb_list tr div.wrap_song_info a[href*='playSong']")
    # 100개의 song정보를 저장할 리스트 선언
    song_list = []
    for song in song_atag:
        # 1개의 song 정보를 저장한 딕셔너리 선언
        song_dict = {}
        title = song.text
        href_value = song['href']
        matched = re.search(r'(\d+)\);', href_value)
        #print(matched.group(0), matched.group(1))
        song_id = matched.group(1)
        song_detail_link = f'https://www.melon.com/song/detail.htm?songId={song_id}'
        song_dict['title'] = title
        song_dict['link'] = song_detail_link
        song_list.append(song_dict)

print(len(song_list))
song_list[0:5]
# Out:
# 200
# 1
# 101
# 200
# 100
# 100
# [{'title': "롤린 (Rollin')",
#   'link': 'https://www.melon.com/song/detail.htm?songId=30287019'},
#  {'title': '라일락',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33372781'},
#  {'title': 'Peaches (Feat. Daniel Caesar & Giveon)',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33359317'},
#  {'title': 'Celebrity',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33239419'},
#  {'title': '운전만해 (We Ride)',
#   'link': 'https://www.melon.com/song/detail.htm?songId=32860397'}]

# %%
import requests
from bs4 import BeautifulSoup
import re

# 요청헤더 
req_header = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36'
}
song_lyric_lists = []
song_lyric_dict = {}

for idx,song in enumerate(song_list,1):
    html = requests.get(song['link'], headers=req_header).text
    soup = BeautifulSoup(html,'html.parser')
    song_lyric_dict['곡명'] = song['title']
    song_lyric_dict['가수'] = soup.select('a[href*=".goArtistDetail"] span')[0].text
    song_lyric_dict['발매일'] = soup.select('div.meta dd')[1].text
    song_lyric_dict['장르'] = soup.select('div.meta dd')[2].text
    print(idx, song['link'])
#    print(soup.select('div#d_video_summary')[0].text)
    if(soup.select('div#d_video_summary')):
        lyric = soup.select('div#d_video_summary')[0].text
    else:
        lyric = ''
    regex = re.compile(r'[\n\r\t]')
    song_lyric_dict['가사'] = regex.sub('', lyric.strip())
# %%
import json

with open('data/songs.json','w', encoding='utf-8') as file:
    json.dump(song_lyric_lists, file)

# %%
import pandas as pd

song_df = pd.read_json('data/songs.json')
song_df.head()
# Out:
#                                        곡명             가수         발매일   장르  \
# 0                            롤린 (Rollin')         브레이브걸스  2017.03.07   댄스
# 1                                     라일락            아이유  2021.03.25   댄스
# 2  Peaches (Feat. Daniel Caesar & Giveon)  Justin Bieber  2021.03.19  POP
# 3                               Celebrity            아이유  2021.03.25   댄스
# 4                          운전만해 (We Ride)         브레이브걸스  2020.08.14   댄스
#
#                                                   가사
# 0  그 날을 잊지 못해 babe날 보며 환히 웃던 너의 미소에홀린 듯 I'm fall ...
# 1  나리는 꽃가루에 눈이 따끔해 (아야)눈물이 고여도 꾹 참을래내 마음 한켠 비밀스런 ...
# 2  I got my peaches out in GeorgiaOh yeah shitI g...
# 3  세상의 모서리구부정하게 커버린골칫거리 outsider걸음걸이, 옷차림, 이어폰 너머...
# 4  넌 운전만 해계속 운전만 해왜 이리 된 걸까 우리 사이가갑자기 어색해졌단 걸왜 달라...

# %%
song_df.sample(5)
# Out:
#                                 곡명           가수         발매일          장르  \
# 36                            기다릴게          하동균  2021.04.22         발라드
# 48         어떻게 지내 (Prod. By VAN.C)    오반 (OVAN)  2020.03.05  랩/힙합, 인디음악
# 18                        Blueming          아이유  2019.11.18        록/메탈
# 93  서른 밤째 (바른연애 길잡이 X 윤하 (YOUNHA))  윤하 (YOUNHA)  2021.02.08         발라드
# 86                    I'm Not Cool           현아  2021.01.28          댄스
#
#                                                    가사
# 36  한걸음 걸어가죠니 모습 눈물에 가리죠내 눈물 밟으며 가까이 가까이다가오는 너초라한 ...
# 48  어떻게 지내 식상한 말이내 가사가 될 줄 몰랐어얼마 안됐네 지나온 날이다 알아도 그...
# 18  ‘뭐해?‘라는 두 글자에‘네가 보고 싶어’ 나의 속마음을 담아 우이모티콘 하나하나 ...
# 93  가만히 누워있길딱 세 시간째멍하니 그저 멍하니자꾸 네가 생각나환히 웃고 있는 네 사...
# 86  말투와 행동을 꾸민 듯 안 꾸며야 해That’s the way I like itTh...

# %%
song_df['가수'].value_counts().head(10)
# Out:
# 아이유                  15
# SG 워너비                6
# 방탄소년단                 4
# 폴킴                    3
# 오마이걸 (OH MY GIRL)     2
# 브레이브걸스                2
# 장범준                   2
# 이예준                   2
# 로제 (ROSÉ)             2
# BLACKPINK             2
# Name: 가수, dtype: int64

# %%
song_df['장르'].value_counts().head(10)
# Out:
# 발라드            34
# 댄스             21
# POP             9
# 랩/힙합            8
# 발라드, 국내드라마      6
# R&B/Soul        6
# 발라드, 인디음악       4
# 록/메탈            4
# 랩/힙합, 인디음악      2
# 록/메탈, 국내드라마     2
# Name: 장르, dtype: int64

# %%
song_df['장르'].unique()
# Out:
# array(['댄스', 'POP', '발라드', 'R&B/Soul', '발라드, 국내드라마', '록/메탈', '랩/힙합',
#        '발라드, 인디음악', '록/메탈, 국내드라마', '인디음악, 포크/블루스', '랩/힙합, 인디음악',
#        'R&B/Soul, 인디음악', '성인가요', '포크/블루스'], dtype=object)

# %%
song_df.loc[song_df['가수'] == '아이유'].sort_values(by='발매일',ascending=False).reset_index(drop=True)
# Out:
#                              곡명   가수         발매일          장르  \
# 0                           라일락  아이유  2021.03.25          댄스
# 1                     Celebrity  아이유  2021.03.25          댄스
# 2                          Coin  아이유  2021.03.25    R&B/Soul
# 3                   어푸 (Ah puh)  아이유  2021.03.25          댄스
# 4                        봄 안녕 봄  아이유  2021.03.25         발라드
# 5                     아이와 나의 바다  아이유  2021.03.25         발라드
# 6                           Flu  아이유  2021.03.25          댄스
# 7             돌림노래 (Feat. DEAN)  아이유  2021.03.25    R&B/Soul
# 8                          에필로그  아이유  2021.03.25         발라드
# 9               빈 컵 (Empty Cup)  아이유  2021.03.25    R&B/Soul
# 10  에잇(Prod.&Feat. SUGA of BTS)  아이유  2020.05.06        록/메탈
# 11                      마음을 드려요  아이유  2020.02.15  발라드, 국내드라마
# 12                     Blueming  아이유  2019.11.18        록/메탈
# 13                    Love poem  아이유  2019.11.01        록/메탈
# 14                      내 손을 잡아  아이유  2011.05.25  발라드, 국내드라마
#
#                                                    가사
# 0   나리는 꽃가루에 눈이 따끔해 (아야)눈물이 고여도 꾹 참을래내 마음 한켠 비밀스런 ...
# 1   세상의 모서리구부정하게 커버린골칫거리 outsider걸음걸이, 옷차림, 이어폰 너머...
# 2   강자에게 더 세게 I love gamble과감할수록 신세계 on my tableI’...
# 3   I’m such a good surfer가라앉지 않기비틀 비 비틀 거리다가 풍덩 u...
# 4   아프던 너의 이름도이제는 미련이 아냐하얗게 잊어버린 듯 살다가또 한 번 마주치고 싶...
# 5   그러나 시간이 지나도아물지 않는 일들이 있지내가 날 온전히 사랑하지 못해서 맘이 가...
# 6   Doc, I’m feeling bad 미열이 흐르고 또 어질어질해there’s to...
# 7   죄책감 없이 밤늦게 전화해도 돼(그 다음 날) 기억도 못 할 헛소릴 뱉어도 돼(아무...
# 8   나를 알게 되어서 기뻤는지나를 사랑해서 좋았었는지우릴 위해 불렀던 지나간 노래들이여...
# 9   창백한 눈으로 날 바라보는넌 변함 없이 빛나날 미치게 하던 그 눈을 더이상사랑하지 ...
# 10  So are you happy nowFinally happy now are you뭐...
# 11  당신에게 드릴 게 없어서나의 마음을 드려요그대에게 받은 게 많아서표현을 다 할 수가...
# 12  ‘뭐해?‘라는 두 글자에‘네가 보고 싶어’ 나의 속마음을 담아 우이모티콘 하나하나 ...
# 13  누구를 위해 누군가 기도하고 있나 봐숨죽여 쓴 사랑시가낮게 들리는 듯해너에게로 선명...
# 14  느낌이 오잖아 떨리고 있잖아언제까지 눈치만 볼 거니네 맘을 말해봐 딴청 피우지 말란...

# %%
# 장르가 댄스 인 곡명,가수,발매일
dance_df = song_df.loc[song_df['장르'] == '댄스', ['곡명','가수','발매일']].reset_index(drop=True)
dance_df.index
# Out:
# RangeIndex(start=0, stop=21, step=1)

# %%
import numpy as np

dance_df.index = np.arange(1,len(dance_df)+1)
dance_df
# Out:
#                                            곡명                 가수         발매일
# 1                                롤린 (Rollin')             브레이브걸스  2017.03.07
# 2                                         라일락                아이유  2021.03.25
# 3                                   Celebrity                아이유  2021.03.25
# 4                              운전만해 (We Ride)             브레이브걸스  2020.08.14
# 5                                    Dynamite              방탄소년단  2020.08.24
# 6       LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)                양요섭  2021.03.05
# 7                                 어푸 (Ah puh)                아이유  2021.03.25
# 8                              Lovesick Girls          BLACKPINK  2020.10.02
# 9                                     Dolphin  오마이걸 (OH MY GIRL)  2020.04.27
# 10                                        Flu                아이유  2021.03.25
# 11  작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)              방탄소년단  2019.04.12
# 12                          How You Like That          BLACKPINK  2020.06.26
# 13                           살짝 설렜어 (Nonstop)  오마이걸 (OH MY GIRL)  2020.04.27
# 14               When We Disco (Duet with 선미)                박진영  2020.08.12
# 15                                       ASAP        STAYC(스테이씨)  2021.04.08
# 16                               I'm Not Cool                 현아  2021.01.28
# 17                              딩가딩가 (Dingga)      마마무 (Mamamoo)  2020.10.20
# 18                                마리아 (Maria)        화사 (Hwa Sa)  2020.06.29
# 19                              Don't Call Me       SHINee (샤이니)  2021.02.22
# 20                                   Panorama      IZ*ONE (아이즈원)  2020.12.07
# 21                                  꼬리 (TAIL)                 선미  2021.02.23

# %%
# !pip show sqlalchemy
# Out:
# Name: SQLAlchemy
# Version: 1.3.20
# Summary: Database Abstraction Library
# Home-page: http://www.sqlalchemy.org
# Author: Mike Bayer
# Author-email: mike_mp@zzzcomputing.com
# License: MIT
# Location: c:\users\vega2\anaconda3\lib\site-packages
# Requires:
# Required-by:

# %%
import pymysql
import sqlalchemy

#pymysql 과 sqlalchemy 연결
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqldb://python:python@localhost:3306/python_db",\
                       encoding='utf-8')
print(engine)
#engine을 사용해서 connection 객체생성
con = engine.connect()
print(con)

song_df.to_sql(name="songs", con=engine, if_exists='replace', index=False)
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
# <sqlalchemy.engine.base.Connection object at 0x000001F9835BBE50>

# %%
#기존 DataFrame 객체의 복사본을 생성함
table_df = song_df.copy()
table_df.head()
# Out:
#                                        곡명             가수         발매일   장르  \
# 0                            롤린 (Rollin')         브레이브걸스  2017.03.07   댄스
# 1                                     라일락            아이유  2021.03.25   댄스
# 2  Peaches (Feat. Daniel Caesar & Giveon)  Justin Bieber  2021.03.19  POP
# 3                               Celebrity            아이유  2021.03.25   댄스
# 4                          운전만해 (We Ride)         브레이브걸스  2020.08.14   댄스
#
#                                                   가사
# 0  그 날을 잊지 못해 babe날 보며 환히 웃던 너의 미소에홀린 듯 I'm fall ...
# 1  나리는 꽃가루에 눈이 따끔해 (아야)눈물이 고여도 꾹 참을래내 마음 한켠 비밀스런 ...
# 2  I got my peaches out in GeorgiaOh yeah shitI g...
# 3  세상의 모서리구부정하게 커버린골칫거리 outsider걸음걸이, 옷차림, 이어폰 너머...
# 4  넌 운전만 해계속 운전만 해왜 이리 된 걸까 우리 사이가갑자기 어색해졌단 걸왜 달라...

# %%
table_df.columns = ['title','singer','release_date','genre','lyric']
table_df.head(2)
# Out:
#           title  singer release_date genre  \
# 0  롤린 (Rollin')  브레이브걸스   2017.03.07    댄스
# 1           라일락     아이유   2021.03.25    댄스
#
#                                                lyric
# 0  그 날을 잊지 못해 babe날 보며 환히 웃던 너의 미소에홀린 듯 I'm fall ...
# 1  나리는 꽃가루에 눈이 따끔해 (아야)눈물이 고여도 꾹 참을래내 마음 한켠 비밀스런 ...

# %%
import numpy as np

table_df.index = np.arange(1,len(table_df)+1)
table_df.tail(3)
# Out:
#                      title      singer release_date genre  \
# 98   다시 만날까 봐 (Prod.V.O.S)         이예준   2021.02.07   발라드
# 99    어떤X (What Type of X)  제시 (Jessi)   2021.03.17  랩/힙합
# 100              꼬리 (TAIL)          선미   2021.02.23    댄스
#
#                                                  lyric
# 98   인스타로 몰래 보는 너의 하루들누가 봐도 헤어진 티를 내팔로우 다 끊고서좋아요는 왜...
# 99   I’m a different type of beastI’m a different t...
# 100  Ah 날 똑바로 쳐다봐처진 고개를 더 세워Umm 온 신경이 곤두서이건 아마도 널할퀸...

# %%
import pymysql
import sqlalchemy

#pymysql과 sqlalchemy 를 연동
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

#'mysql+mysqldb://scott:tiger@localhost/foo'
#Engine 객체 생성
engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                      encoding='utf-8')
print(engine)
#Engine을 사용해서 DB에 연결 
con = engine.connect()
print(con)

#['곡명', '가수', '앨범', '발매일', '장르', '가사']
#DataFrame의 to_sql() 함수로 dataframe 객체를 Table로 저정
table_df.to_sql(name='songs100', con=engine, if_exists='replace', index=True,\
              index_label='id',
              dtype={
                  'id':sqlalchemy.types.INTEGER(),
                  'title':sqlalchemy.types.VARCHAR(100),
                  'singer':sqlalchemy.types.VARCHAR(100),
                  'release_date':sqlalchemy.DATE,
                  'genre':sqlalchemy.types.VARCHAR(100),
                  'lyric':sqlalchemy.types.VARCHAR(2500)
              })
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
# <sqlalchemy.engine.base.Connection object at 0x000001F9835ABCA0>

# %%
import pymysql
import sqlalchemy

#pymysql과 sqlalchemy 를 연동
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

#'mysql+mysqldb://scott:tiger@localhost/foo'
#Engine 객체 생성
engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                      encoding='utf-8')
print(engine)
#Engine을 사용해서 DB에 연결 
con = engine.connect()
songs100_df=pd.read_sql_table('songs100',con)

#DB 연결 종료
con.close()

songs100_df.head()
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
#    id                                   title         singer release_date  \
# 0   1                            롤린 (Rollin')         브레이브걸스   2017-03-07
# 1   2                                     라일락            아이유   2021-03-25
# 2   3  Peaches (Feat. Daniel Caesar & Giveon)  Justin Bieber   2021-03-19
# 3   4                               Celebrity            아이유   2021-03-25
# 4   5                          운전만해 (We Ride)         브레이브걸스   2020-08-14
#
#   genre                                              lyric
# 0    댄스  그 날을 잊지 못해 babe날 보며 환히 웃던 너의 미소에홀린 듯 I'm fall ...
# 1    댄스  나리는 꽃가루에 눈이 따끔해 (아야)눈물이 고여도 꾹 참을래내 마음 한켠 비밀스런 ...
# 2   POP  I got my peaches out in GeorgiaOh yeah shitI g...
# 3    댄스  세상의 모서리구부정하게 커버린골칫거리 outsider걸음걸이, 옷차림, 이어폰 너머...
# 4    댄스  넌 운전만 해계속 운전만 해왜 이리 된 걸까 우리 사이가갑자기 어색해졌단 걸왜 달라...

# %%
def search_song(singer,title):
    sql = """select * from songs100 where singer like %s and title like %s;"""
    
    import pymysql
    import sqlalchemy

    #pymysql과 sqlalchemy 를 연동
    pymysql.install_as_MySQLdb()
    from sqlalchemy import create_engine

    #'mysql+mysqldb://scott:tiger@localhost/foo'
    #Engine 객체 생성
    engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                          encoding='utf-8')
    print(engine)
    #Engine을 사용해서 DB에 연결 
    con = engine.connect()
    
    singer = f'%{singer}%'
    title = f'%{title}%'
    
    result = pd.read_sql_query(sql,con=con, params=(singer,title))
    
    con.close()
    
    return result

# %%
search_song('아','a')
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
#      id                                          title         singer  \
# 0     2                                            라일락            아이유
# 1     3         Peaches (Feat. Daniel Caesar & Giveon)  Justin Bieber
# 2     4                                      Celebrity            아이유
# 3     9                                           Coin            아이유
# 4    10                                        내 손을 잡아            아이유
# 5    11                                       Dynamite          방탄소년단
# 6    13          LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)            양요섭
# 7    19                                       Blueming            아이유
# 8    20                    에잇(Prod.&Feat. SUGA of BTS)            아이유
# 9    22         VVS (Feat. JUSTHIS) (Prod. GroovyRoom)   미란이 (Mirani)
# 10   23                                    어푸 (Ah puh)            아이유
# 11   30                                         봄 안녕 봄            아이유
# 12   36   Savage Love (Laxed - Siren Beat) (BTS Remix)      Jawsh 685
# 13   38                                      아이와 나의 바다            아이유
# 14   43                                            Flu            아이유
# 15   44          모든 날, 모든 순간 (Every day, Every Moment)             폴킴
# 16   45                               사실 나는 (Feat.전건호)           경서예지
# 17   46  사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)            호미들
# 18   49                        어떻게 지내 (Prod. By VAN.C)      오반 (OVAN)
# 19   52       오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)   마크툽 (MAKTUB)
# 20   53      작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)          방탄소년단
# 21   55                              How You Like That      BLACKPINK
# 22   56                              돌림노래 (Feat. DEAN)            아이유
# 23   60                                        마음을 드려요            아이유
# 24   66                                   Dance Monkey    Tones And I
# 25   67                                      Love poem            아이유
# 26   72                                           ASAP    STAYC(스테이씨)
# 27   74                                           에필로그            아이유
# 28   77         내일이 오면 (Feat. 기리보이, BIG Naughty (서동현))   릴보이 (lIlBOI)
# 29   80                              Paris In The Rain           Lauv
# 30   82                                Don't Start Now       Dua Lipa
# 31   85                                  Downtown Baby      블루 (BLOO)
# 32   87                                   I'm Not Cool             현아
# 33   89                                         Maniac     Conan Gray
# 34   90                                  딩가딩가 (Dingga)  마마무 (Mamamoo)
# 35   92                                    마리아 (Maria)    화사 (Hwa Sa)
# 36   94                 서른 밤째 (바른연애 길잡이 X 윤하 (YOUNHA))    윤하 (YOUNHA)
# 37   95                                  Don't Call Me   SHINee (샤이니)
# 38   96                                빈 컵 (Empty Cup)            아이유
# 39   97                                       Panorama  IZ*ONE (아이즈원)
# 40   99                           어떤X (What Type of X)     제시 (Jessi)
# 41  100                                      꼬리 (TAIL)             선미
#
#    release_date           genre  \
# 0    2021-03-25              댄스
# 1    2021-03-19             POP
# 2    2021-03-25              댄스
# 3    2021-03-25        R&B/Soul
# 4    2011-05-25      발라드, 국내드라마
# 5    2020-08-24              댄스
# 6    2021-03-05              댄스
# 7    2019-11-18            록/메탈
# 8    2020-05-06            록/메탈
# 9    2020-11-21            랩/힙합
# 10   2021-03-25              댄스
# 11   2021-03-25             발라드
# 12   2020-10-02             POP
# 13   2021-03-25             발라드
# 14   2021-03-25              댄스
# 15   2018-03-20      발라드, 국내드라마
# 16   2020-04-12             발라드
# 17   2021-03-20            랩/힙합
# 18   2020-03-05      랩/힙합, 인디음악
# 19   2019-06-09  R&B/Soul, 인디음악
# 20   2019-04-12              댄스
# 21   2020-06-26              댄스
# 22   2021-03-25        R&B/Soul
# 23   2020-02-15      발라드, 국내드라마
# 24   2019-08-09             POP
# 25   2019-11-01            록/메탈
# 26   2021-04-08              댄스
# 27   2021-03-25             발라드
# 28   2020-12-05            랩/힙합
# 29   2018-10-08             POP
# 30   2019-11-01             POP
# 31   2017-12-06      랩/힙합, 인디음악
# 32   2021-01-28              댄스
# 33   2019-10-25             POP
# 34   2020-10-20              댄스
# 35   2020-06-29              댄스
# 36   2021-02-08             발라드
# 37   2021-02-22              댄스
# 38   2021-03-25        R&B/Soul
# 39   2020-12-07              댄스
# 40   2021-03-17            랩/힙합
# 41   2021-02-23              댄스
#
#                                                 lyric
# 0   나리는 꽃가루에 눈이 따끔해 (아야)눈물이 고여도 꾹 참을래내 마음 한켠 비밀스런 ...
# 1   I got my peaches out in GeorgiaOh yeah shitI g...
# 2   세상의 모서리구부정하게 커버린골칫거리 outsider걸음걸이, 옷차림, 이어폰 너머...
# 3   강자에게 더 세게 I love gamble과감할수록 신세계 on my tableI’...
# 4   느낌이 오잖아 떨리고 있잖아언제까지 눈치만 볼 거니네 맘을 말해봐 딴청 피우지 말란...
# 5   Cos ah ahI’m in the stars tonightSo watch me b...
# 6   참 많이 궁금해전부 다 궁금해왜 잠이 안 오고 네 얼굴만 보여나도 궁금해이 맘이 궁...
# 7   ‘뭐해?‘라는 두 글자에‘네가 보고 싶어’ 나의 속마음을 담아 우이모티콘 하나하나 ...
# 8   So are you happy nowFinally happy now are you뭐...
