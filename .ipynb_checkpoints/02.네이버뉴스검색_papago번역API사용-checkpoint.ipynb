# %% [markdown]
# #### 1. Library import

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
url = 'https://news.naver.com/'
# 요청헤더 
req_header = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36'
}
# get() 요청 보내기
res =requests.get(url, headers=req_header)
print('응답코드 {}'.format(res.status_code))

if res.ok:
    # response 객체에서 텍스트 추출
    html = res.text
    # 추출한 텍스트를 파싱하기 위해서 BeautifulSoup 객체생성
    soup = BeautifulSoup(html, 'html.parser')
    #print(soup)
    print(len(soup.select('div')))
# Out:
# 응답코드 200
# 327
# [<div id="wrap">
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_wrap">
# <!-- GNB 마크업 -->
# <div id="gnb"></div>
# <!-- //GNB 마크업 -->
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(STA.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(STA.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="nclicks(STA.enter)" href="https://entertain.naver.com/home"><img alt="TV연예" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_entertain.png" width="52"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.sports)" href="https://sports.news.naver.com"><img alt="스포츠" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_sports.png" width="48"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.newsstand)" href="https://newsstand.naver.com"><img alt="뉴스스탠드" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_newsstand.png" width="77"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.weather)" href="https://weather.naver.com"><img alt="날씨" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_weather.png" width="31"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li class="lnb_menu_home on"><a class="nclicks(LNB.home)" href="/main/home.nhn"><span class="tx">뉴스홈</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(LNB.flash)" href="/main/list.nhn?mode=LSD&amp;mid=sec&amp;sid1=001"><span class="tx">속보</span></a></li>
# <li><a class="nclicks(LNB.pol)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li><a class="nclicks(LNB.eco)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(LNB.soc)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(LNB.lif)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(LNB.wor)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(LNB.sci)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(LNB.opi)" href="/main/opinion/home.nhn"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(LNB.pho)" href="/main/photo/index.nhn?mid=pho"><span class="tx">포토</span> </a></li>
# <li><a class="nclicks(LNB.tv)" href="/main/tv/index.nhn?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(LNB.ranking)" href="/main/ranking/popularDay.nhn?mid=etc&amp;sid1=111"><span class="tx">랭킹뉴스</span> </a></li>
# </ul>
# <form accept-charset="UTF-8" action="https://search.naver.com/search.naver" id="lnb.searchForm" method="get" name="lnb_searchForm" target="_blank">
# <fieldset>
# <legend>뉴스 검색</legend>
# <input accesskey="s" class="text_index" name="query" style="ime-mode:active;" title="뉴스 검색" type="text"/>
# <input name="where" type="hidden" value="news"/>
# <input name="ie" type="hidden" value="utf8"/>
# <input name="sm" type="hidden" value="nws_hty"/>
# <button class="btn_search_lnb nclicks(LNB.search)" type="submit"><span class="tx"><span class="blind">검색</span></span></button>
# </fieldset>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="home_timelate">
# <div class="ht_head">
# <ul class="ht_tabmnu">
# <li id="ht_tabmnu_0">
# <a href="#" title="신문 헤드라인">신문 헤드라인<span class="ht_ico"></span></a>
# </li>
# <li id="ht_tabmnu_1">
# <a href="#" title="저녁 방송 뉴스">저녁 방송 뉴스<span class="ht_ico"></span></a>
# </li>
# </ul>
# <ul class="lnb_side" tabindex="0">
# <li>
# <a class="nclicks(nct.right1)" href="https://news.naver.com/main/factcheck/main.nhn" title="팩트체크">팩트체크
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right2)" href="https://media.naver.com/channel/settings.nhn  " target="_blank" title="언론사 구독 ">언론사 구독
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right3)" href="https://news.naver.com/main/officeList.nhn" title="언론사 뉴스">언론사 뉴스
# </a>
# </li>
# <li class="end">
# <a class="nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리
# </a>
# </li>
# </ul>
# </div>
# <div class="ht_comp ht_paperheadline" id="paperHeadlineRolling" style="display: none;">
# <h3 class="blind">신문 헤드라인</h3>
# <ul class="ht_ph_lst" style="display: none;">
# <!-- 헤드라인 데이터 동적삽입 <li> -->
# </ul>
# <div class="ht_nodata_all" style="display: none;">발행된 종이신문이 없거나 신문게재 정보가 입력되지 않았습니다.</div>
# <div class="ht_navi">
# <a class="ht_btn_prev nclicks(opt.prev)" href="javascript:;"><span class="ht_ico"></span><span class="blind">이전</span></a>
# <a class="ht_btn_next nclicks(opt.next)" href="javascript:;"><span class="ht_ico"></span><span class="blind">다음</span></a>
# <a class="ht_btn_fold nclicks(opt.open)" href="javascript:;"><span class="ht_btn_box"><span class="ht_btn_ico"></span><span class="blind">접기</span></span></a>
# </div>
# </div>
# <div class="ht_comp ht_eveningnews" id="eveningNewsRolling" style="display: none;">
# <h3 class="blind">저녁 방송 뉴스</h3>
# <ul class="ht_ph_lst">
# <!-- 저녁방송뉴스 동적삽입 <li> -->
# </ul>
# <div class="ht_navi">
# <a class="ht_btn_prev nclicks(opt.prev);" href="javascript:;"><span class="ht_ico"></span><span class="blind">이전</span></a>
# <a class="ht_btn_next nclicks(opt.next)" href="javascript:;"><span class="ht_ico"></span><span class="blind">다음</span></a>
# <a class="ht_btn_fold nclicks(opt.open)" href="javascript:;"><span class="ht_btn_box"><span class="ht_btn_ico"></span><span class="blind">접기</span></span></a>
# </div>
# </div>
# <script type="text/javascript">
# _oTopComponentData = {
# "open" : "N",
# "target" : "headlineList",
# "headlineList" : [
# {
# "officeId" : "030",
# "officeName" : "전자신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/030/2017/01/05/logo_030_1_20170105110505.gif' width='206' height='30' alt='전자신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/030/2021/04/27/2941605.jpg?type=nf80_54",
# "title" : "2022 교육과정 \'AI·디지털\' 겉핥기...\"인재양성 비전 실종\"",
# "summary" : "\'2022 교육과정\'에 인공지능(AI)·디지털 내용이 후순위로 밀렸다. 정보화(SW)교육 필수화를 담은 \'2015 개정 교육과정\'보다도 뒤처졌다는 평가다. 4차 산업혁명 시대에 필요한 인재의 양성 요구가 높지만 정작",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "032",
# "officeName" : "경향신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/032/2017/01/05/logo_032_1_20170105110505.gif' width='206' height='30' alt='경향신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/032/2021/04/27/3071312.jpg?type=nf80_54",
# "title" : "아빠 성 따르는 원칙·‘혼외자’ 구분 없앤다",
# "summary" : "[경향신문] 정부가 아버지의 성(姓)을 우선 따르게 하는 원칙을 폐기하고 부모가 협의해 결정하도록 하는 방안을 추진한다. ‘혼외자’ 같은 차별적 용어를 각종 법령에서 쓰지 않고 혼인·혈연 테두리 밖에 있는 비혼 동거",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "011",
# "officeName" : "서울경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/011/2017/01/05/logo_011_1_20170105110505.gif' width='206' height='30' alt='서울경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/011/2021/04/27/3902936.jpg?type=nf80_54",
# "title" : "K조선 르네상스, 친환경 선박에 달렸다",
# "summary" : "[서울경제] 지난해 신종 코로나바이러스 감염증(코로나19) 사태로 적자의 수렁에 빠졌던 한국 조선 업계가 수주에 박차를 가하고 있다. 모처럼 업황이 기지개를 켜며 부활의 바다로 나아가고 있는 것이다. 하지만 이전의 ",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "353",
# "officeName" : "중앙SUNDAY",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/353/2018/03/17/logo_353_1_20180317103917.png' width='206' height='30' alt='중앙SUNDAY' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "277",
# "officeName" : "아시아경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/277/2017/01/05/logo_277_1_20170105110505.gif' width='206' height='30' alt='아시아경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/277/2021/04/28/4893413.jpg?type=nf80_54",
# "title" : "철광석·구리 사상최고치…또 경고음 커진 인플레",
# "summary" : "[아시아경제 뉴욕=백종민 특파원, 박병희 기자, 이동우 기자] 산업계 핵심 원자재인 철광석과 구리 가격이 사상최고치로 치솟아 인플레이션 위험이 다시 커지고 있다. 철광석과 같은 원자재를 실어나르는 벌크선 운임지수(B",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "014",
# "officeName" : "파이낸셜뉴스",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/014/2017/01/05/logo_014_1_20170105110505.gif' width='206' height='30' alt='파이낸셜뉴스' title='' class='' >",
# "thumbnail" : "",
# "title" : "부동산에 코인까지.. 표따라 널뛰는 세금",
# "summary" : "포퓰리즘(인기 영합주의) 회오리에 정부 조세정책의 근간이 흔들리고 있다. 4·7 선거에 패배한 여당이 부동산특별위원회를 통해 종합부동산세와 재산세 등 부동산 세제 완화 법안에 대해 논의한다는 입장을 밝혔기 때문이다.",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "015",
# "officeName" : "한국경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/015/2017/01/05/logo_015_1_20170105110505.gif' width='206' height='30' alt='한국경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/015/2021/04/27/4537400.jpg?type=nf80_54",
# "title" : "AI發 \'마의 벽\'에 부딪힌 자율주행차",
# "summary" : "‘국내 자율주행자동차 주행시험 중 첫 도로 추돌 사고’(2020년 12월), ‘테슬라 미시간주 경찰차 추돌 사고’(2021년 3월), ‘테슬라 오토파일럿 관련 사고’(2021년 4월)…. ‘4차 산업혁명의 꽃’으로 ",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "016",
# "officeName" : "헤럴드경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/016/2017/01/05/logo_016_1_20170105110505.gif' width='206' height='30' alt='헤럴드경제' title='' class='' >",
# "thumbnail" : "",
# "title" : "이건희 회장의 ‘위대한 유산’...전재산 60% 사회환원",
# "summary" : "고(故) 이건희 삼성전자 회장이 보유한 전 재산 가운데 60% 상당이 사회에 환원된다. 28일 삼성그룹과 이 회장의 유족들은 “12조원 이상의 상속세를 납부하는 동시에 의료 공헌과 미술품 기증 등으로 사회환원을 실천",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "018",
# "officeName" : "이데일리",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/018/2017/01/05/logo_018_1_20170105110505.gif' width='206' height='30' alt='이데일리' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/018/2021/04/28/4913871.jpg?type=nf80_54",
# "title" : "오세훈-정부 엇박자에 집값 ‘껑충’…稅부담만 커질라",
# "summary" : "[이데일리 강신우 기자] “서울, 특히 강남4구에서 아파트 가격상승폭이 다시 V자를 그리고 있다. 재건축 기대감 형성 때문이다.”(홍남기 국무총리 직무대행 겸 경제부총리) 오세훈 서울시장이 재건축·재개발 등 민간 정",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "081",
# "officeName" : "서울신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/081/2017/01/05/logo_081_1_20170105110505.gif' width='206' height='30' alt='서울신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/081/2021/04/27/3182191.jpg?type=nf80_54",
# "title" : "‘제도’ 마련 없이… 홍남기 “가상자산 과세”",
# "summary" : "홍남기 국무총리 직무대행 겸 경제부총리는 27일 “가상자산(암호화폐 등) 거래로 발생한 소득에 대해선 조세형평성상 과세하지 않을 수 없다”고 말했다. 여당 일각에서 제기되고 있는 암호화폐 과세 유예 움직임에 대해 반",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "082",
# "officeName" : "부산일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/082/2021/01/15/logo_082_1_20210115134425.png' width='206' height='30' alt='부산일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/082/2021/04/27/1086474.jpg?type=nf80_54",
# "title" : "장관 승인 사업도 ‘태클’… 도 넘은 ‘해수부 월권’",
# "summary" : "부산일보DB 트램(노면전차) 사업을 비롯한 부산항 북항 공공콘텐츠 사업 전체를 표류 위기에 빠뜨린 해양수산부의 ‘북항추진단 및 북항 재개발 사업 표적감사’ 논란(부산일보 4월 26일 자 1·4면 보도)이 올해 2월 ",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "020",
# "officeName" : "동아일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/020/2017/01/05/logo_020_1_20170105110505.gif' width='206' height='30' alt='동아일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/020/2021/04/28/3353963.jpg?type=nf80_54",
# "title" : "출생신고때 엄마姓 따를 수 있게 법 바꾼다",
# "summary" : "정부가 2025년까지 아동이 아버지 성을 따르도록 하는 ‘부성(父姓) 우선’ 원칙을 폐기하기로 했다. 혼인신고를 하지 않은 이른바 ‘비혼 커플’도 법적인 가족으로 인정하고 복지정책과 상속 등에서 불이익을 받지 않도록",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "087",
# "officeName" : "강원일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/087/2021/01/15/logo_087_1_20210115134053.png' width='206' height='30' alt='강원일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/087/2021/04/28/841960.jpg?type=nf80_54",
# "title" : "철도망 기대에 땅값 쑥쑥 속초 전국 3위·양양 4위",
# "summary" : "속초 1.247%·양양 1.155% 올라 역세권·해안가 토지 투자 급증 속초와 양양지역 땅값이 전국 광역자치도에서 최고 수준의 상승세를 기록했다. 천혜의 자연환경과 교통망 개발 기대감으로 동해안 토지가격이 고공행진을",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "021",
# "officeName" : "문화일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/021/2017/01/05/logo_021_1_20170105110505.gif' width='206' height='30' alt='문화일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/021/2021/04/28/2469050.jpg?type=nf80_54",
# "title" : "삼성家, 미술품 등 이건희 유산 60% 사회환원",
# "summary" : "■ 유산 26兆 중 15.6兆 추정 단원 김홍도 작품 ‘추성부도’ 등 미술품 2만3000점 2兆~3兆 기증 감염병 전문병원 건립 등 7000억 희귀질환 아동치료 3000억 출연 상속세 납부 12兆 역대최고 금액 삼성",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "088",
# "officeName" : "매일신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/088/2021/01/15/logo_088_1_20210115134127.png' width='206' height='30' alt='매일신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/088/2021/04/27/700327.jpg?type=nf80_54",
# "title" : "네이버·넥슨 등 공격적 채용… IT 기업들 인재 유출 \'비상\'",
# "summary" : "대구 소프트웨어 기업 A사는 지난해 공공기관으로부터 수주받은 시스템 유지관리 프로젝트에 큰 차질을 빚었다. 프로젝트를 맡고 있던 5~7년 차 개발자 4명이 이직을 이유로 급작스레 퇴사하는 바람에 정상적인 진행이 어려",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "022",
# "officeName" : "세계일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/022/2017/01/05/logo_022_1_20170105110505.gif' width='206' height='30' alt='세계일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/022/2021/04/28/3575647.jpg?type=nf80_54",
# "title" : "“혼인·혈연 아니어도 가족”… ‘4차 건강가정계획’ 쟁점과 논란 [뉴스+]",
# "summary" : "엄마 姓도 쓸 수 있게 법개정 추진 성평등 등 사회적 추세·다양성 반영 미혼부 자녀 출생신고 요건 완화 급하게 추진 땐 사회적 혼란 야기 동거·사실혼 부부·위탁가족 대상 포함 사유리 같은 비혼 출산도 인정 방침 종교",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "044",
# "officeName" : "코리아헤럴드",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/044/2017/01/05/logo_044_1_20170105110505.gif' width='206' height='30' alt='코리아헤럴드' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/044/2021/04/27/227388.jpg?type=nf80_54",
# "title" : "‘When can I get my shot?’ Vaccine envy grips Koreans",
# "summary" : "Vaccine envy is spreading among pandemic-weary Koreans, as the country trails behind most major economies in vaccination",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "023",
# "officeName" : "조선일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/023/2017/01/05/logo_023_1_20170105110505.gif' width='206' height='30' alt='조선일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/023/2021/04/27/3610680.jpg?type=nf80_54",
# "title" : "“작은 별빛이 되고 싶다” 90세 정진석 추기경 선종",
# "summary" : "생전 마지막 말 “모두가 행복하길” 각막·장기 기증, 다주고 떠났다 ‘혜화동 할아버지\'가 봄 하늘의 작은 별이 되어 떠났다. 한국의 두 번째 추기경인 정진석(90) 추기경이 27일 선종(善終)했다. 정 추기경은 지난",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "025",
# "officeName" : "중앙일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/025/2018/08/03/logo_025_1_20180803103703.jpg' width='206' height='30' alt='중앙일보' title='' class='' >",
# "thumbnail" : "",
# "title" : "[view] 문 대통령·바이든 자꾸만 어긋난다",
# "summary" : "미국이 여유분의 아스트라제네카(AZ) 백신 6000만 회분을 외국에 지원하기로 했다. 문재인 대통령이 ‘백신 개발국의 자국 우선주의’와 ‘강대국들의 백신 사재기’를 비판한 직후다. 젠 사키 미 백악관 대변인은 지난 ",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "005",
# "officeName" : "국민일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/005/2017/01/05/logo_005_1_20170105110505.gif' width='206' height='30' alt='국민일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/005/2021/04/28/1434513.jpg?type=nf80_54",
# "title" : "[단독] 집값 급등·원전 기소·고용 폭망에도… 평가는‘우수’",
# "summary" : "경제 정책을 책임지는 정부 부처들이 지난해 집값 폭등과 코로나19로 인한 고용 한파 등 경제 난맥상 와중에도 자체 평가 보고서에서 관련 정책이 우수한 성과를 냈다고 자화자찬한 것으로 27일 확인됐다. 정책 성과를 높",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "028",
# "officeName" : "한겨레",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/028/2017/01/05/logo_028_1_20170105110505.gif' width='206' height='30' alt='한겨레' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/028/2021/04/27/2542219.jpg?type=nf80_54",
# "title" : "정진석 추기경 선종…각막과 통장 잔액 기증",
# "summary" : "천주교 서울대교구장을 지낸 정진석 추기경이 27일 오후 10시15분께 서울성모병원에서 선종했다. 향년 90. 정 추기경은 지난 2월21일 몸에 심한 통증을 느낀 뒤 주변 권고로 서울성모병원에 입원해 치료를 받아왔다.",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "029",
# "officeName" : "디지털타임스",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/029/2018/07/18/logo_029_1_20180718140618.jpg' width='206' height='30' alt='디지털타임스' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/029/2021/04/27/2670191.jpg?type=nf80_54",
# "title" : "美中 `백신외교` 전면전",
# "summary" : "서로 \"인도 의료 원조 하겠다\" 중국의 적극적 백신외교 행보에 美 \"아스트라 6000만회분\" 견제 일각 \'백신 글로벌 정치화\' 우려 적극적인 \'백신외교\'를 펼쳐온 중국에 이어 미국도 본격적인 백신원조에 나섰다. 코로",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "469",
# "officeName" : "한국일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/469/2018/01/26/logo_469_1_20180126174326.gif' width='206' height='30' alt='한국일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/469/2021/04/28/600511.jpg?type=nf80_54",
# "title" : "가상화폐 두고 온도차... 민주 \"세심한 정책 필요\" vs 정부 \"투자자 책임\"",
# "summary" : "더불어민주당 지도부는 27일 가상화폐 시장에 대한 정책 지원을 공식화했다. 가상화폐를 새로운 투자 수단으로 보고 투자자 보호 등의 대책 마련에 나서겠다는 것이다. 가상화폐를 \'인정할 수 없는 화폐\'라고 규정하면서 거",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "008",
# "officeName" : "머니투데이",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/008/2017/01/05/logo_008_1_20170105110505.gif' width='206' height='30' alt='머니투데이' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/008/2021/04/27/4578926.jpg?type=nf80_54",
# "title" : "주요국 중 1위로 코로나 이전 경제 회복했다지만…소비는 아직",
# "summary" : "[머니투데이 고석용 기자, 유효송 기자] 국내 경제가 1년 만에 코로나19(COVID-19) 이전 수준으로 회복했다. 주요국들 가운데 가장 빠른 속도다. 그러나 수출에 비해 민간소비 회복세는 더디다는 평가다. 27일",
# "publishDate" : "20210428"
# },
# {
# "officeId" : "009",
# "officeName" : "매일경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/009/2017/01/05/logo_009_1_20170105110505.gif' width='206' height='30' alt='매일경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/009/2021/04/27/4785878.jpg?type=nf80_54",
# "title" : "수수료 없앤 증권사로 퇴직연금 \'밀물\'",
# "summary" : "개인형퇴직연금 수수료 면제에 삼성증권 신규계좌 5배 늘어나 미래에셋도 내달부터 면제나서 증권사 운용수익률이 더 높아 은행·보험서 자금 무더기 이동 ◆ 퇴직연금시장 격변 ◆ 미래에셋증권이 개인형퇴직연금(IRP) 수수료",
# "publishDate" : "20210428"
# }
# ]
# ,
# "liveTvList" : [
# {
# "officeId" : "422",
# "articleId" : "0000482554",
# "sectionId" : "74f",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/422/2018/01/10/logo_422_1_20180110175610.png' width='206' height='30' alt='연합뉴스TV 뉴스리뷰' title='' class='' >",
# "officeName" : "연합뉴스TV",
# "title" : "신규 확진 이틀 연속 500명대…변이 86명 늘어",
# "newsKey" : "74f",
# "naverTvChannelId" : "yonhapnewstv",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/422/2021/04/27/482554.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[뉴스리뷰] [앵커] 지난주 한때 800명에 육박했던 코로나19 신규 확진자 숫자가 이틀째 500명대를 기록했습니다. 하지만 일상 속 감염이 끊이지 않는 데다 위중증 환자도 급증하는 추세입니다. 무엇보다 변이 바이러",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "449",
# "articleId" : "0000207917",
# "sectionId" : "74b",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/449/2018/01/10/logo_449_1_20180110175910.png' width='206' height='30' alt='채널A 뉴스A' title='' class='' >",
# "officeName" : "채널A",
# "title" : "부성 우선 원칙 폐지된다…출생신고 때 결정",
# "newsKey" : "74b",
# "naverTvChannelId" : "channelanews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/449/2021/04/27/207917.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "뉴스A 동정민입니다. 오늘 정부가 가족 형태를 넓히겠다며, 건강가정 기본계획안을 국무회의에서 확정했습니다. 내용을 들여다보면, 가족 붕괴냐, 확장이냐 논란을 불 지필 정도로 변화 정도가 큽니다. 동거 커플도 가족으로",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "437",
# "articleId" : "0000264879",
# "sectionId" : "742",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/437/2018/01/10/logo_437_1_20180110175610.png' width='206' height='30' alt='JTBC 뉴스룸' title='' class='' >",
# "officeName" : "JTBC",
# "title" : "\'아빠 성\' 따르는 원칙 폐기…미혼부 출생신고도 가능하도록",
# "newsKey" : "742",
# "naverTvChannelId" : "jtbcnews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/437/2021/04/27/264879.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[앵커] 오늘(27일) 뉴스룸이 가장 먼저 던질 화두는 가족입니다. 혼인과 혈연을 고집하는 이른바 \'정상가족\'의 신화는 이미 깨지고 있습니다. 하지만, 우리의 제도는 현실을 담아내기엔 너무 낡았고, 새로운 흐름을 따",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "056",
# "articleId" : "0011033563",
# "sectionId" : "355",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/056/2018/01/10/logo_056_1_20180110175610.png' width='206' height='30' alt='KBS 뉴스9' title='' class='' >",
# "officeName" : "KBS",
# "title" : "내수·수출 쌍끌이…“코로나 이전 수준 회복”",
# "newsKey" : "355",
# "naverTvChannelId" : "kbsnews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/056/2021/04/27/11033563.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : " [앵커] 안녕하십니까? 9시 뉴스입니다. 우리 경제 올해 1분기 성적표가 나왔습니다. 아직 경기 회복을 체감하기 어려운 상황인데 수치로만 보면 코로나19 이전 수준을 회복했다는 것이 한국은행과 정부의 설명입니다. ",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "214",
# "articleId" : "0001115172",
# "sectionId" : "370",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/214/2018/01/10/logo_214_1_20180110175710.png' width='206' height='30' alt='MBC 뉴스데스크' title='' class='' >",
# "officeName" : "MBC",
# "title" : "\"노바백스 \'기술 이전·국내 생산\' 내년까지 연장 추진\"",
# "newsKey" : "370",
# "naverTvChannelId" : "imnews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/214/2021/04/27/1115172.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[뉴스데스크] ◀ 앵커 ▶ 코로나19 백신을 해외 제약사에 의존하지 않고 국내 기업한테서 곧바로 공급받을 수 있는 길, 바로 미국 제약사 노바백스가 국내 기업 SK바이오사이언스에 제조 기술을 이전해주기로 하면서 가능",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "057",
# "articleId" : "0001571915",
# "sectionId" : "74e",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/057/2020/06/12/logo_057_1_20200612153812.jpg' width='206' height='30' alt='MBN 종합뉴스' title='' class='' >",
# "officeName" : "MBN",
# "title" : "김주하 앵커가 전하는 4월 27일 종합뉴스 주요뉴스",
# "newsKey" : "74e",
# "naverTvChannelId" : "mbnnews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/057/2021/04/27/1571915.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "▶ \'아버지 성 우선\' 폐기…\"비혼동거도 가족\" 자녀가 태어나면 아버지 성을 우선 따르도록 하는 원칙을 폐기하고 부모가 협의해 어머니 성을 쓸 수 있도록 법 개정이 추진됩니다. 정부는 또 혼인과 혈연 중심의 법을 고",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "055",
# "articleId" : "0000890529",
# "sectionId" : "371",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/055/2018/01/10/logo_055_1_20180110175610.png' width='206' height='30' alt='SBS 8뉴스' title='' class='' >",
# "officeName" : "SBS",
# "title" : "오늘의 주요뉴스",
# "newsKey" : "371",
# "naverTvChannelId" : "sbsnews8",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/055/2021/04/27/890529.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "1. 정부가 가족의 범위를 비혼 동거 커플이나 위탁가족 등으로 넓히는 방안을 추진합니다. 출생신고 때 자녀의 성을 아버지나 어머니 성 가운데 선택할 수 있도록 하는 방안도 추진됩니다. ▷ \'가족\' 달라진다…비혼 동거",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "448",
# "articleId" : "0000326420",
# "sectionId" : "750",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/448/2018/08/30/logo_448_1_20180830162730.png' width='206' height='30' alt='TV조선 뉴스9' title='' class='' >",
# "officeName" : "TV조선",
# "title" : "당정, 가상화폐 \'충돌\'…홍남기 \"화폐 아냐\" vs 與 \"투자 보호\"",
# "newsKey" : "750",
# "naverTvChannelId" : "tvchosunnews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/448/2021/04/27/326420.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[앵커] 가상화폐를 둘러싼 논란이 우리 사회 전체를 불안 속으로 몰아넣고 있습니다. 당장 돈을 벌었다는 사람도 많지만 그 못지않게 피해를 본 사람들이 속출하고 있습니다. 하지만 책임이 있는 정부 여당은 여전히 가상화",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "052",
# "articleId" : "0001580939",
# "sectionId" : "751",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/052/2018/01/10/logo_052_1_20180110175810.png' width='206' height='30' alt='YTN 뉴스나이트' title='' class='' >",
# "officeName" : "YTN",
# "title" : "[날씨] 밤사이 서울 등 중부 지방 비...내일 황사 유입",
# "newsKey" : "751",
# "naverTvChannelId" : "ytnnews24",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/052/2021/04/27/1580939.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "밤사이 서울 등 중부 지방에는 비가 조금 내리겠습니다. 비는 내일 새벽에 대부분 그치겠는데요. 다만 비구름의 뒤를 따라 황사가 유입되겠습니다. 이에 따라 내일 전국의 미세먼지 농도가 나쁨에서 매우 나쁨 수준까지 치솟",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# }
# ]
# };
# </script>
# </div>
# <script type="text/javascript">
# 	// page onload 시에 home timelate에서 사용하는 스크립트를 초기화 시켜준다.
# 	jindo.$Fn(function(){
# 		try {
# 			news.home.TopTimelate.Controller.init(_oTopComponentData);
# 		} catch (e) { }
# 	}).attach(window, "load");
# </script>
# <div class="main_space"></div>
# <div class="main" id="container">
# <hr/>
# <div class="main_content main_content_new" id="main_content">
# <div class="main_content_inner _content_inner">
# <div class="main_component droppable" id="today_main_news">
# <div class="com_header">
# <h4 class="tit_h4 tit_main1"><strong>헤드라인 뉴스</strong></h4>
# <p class="news_info_txt">헤드라인 뉴스와 각 기사묶음 타이틀은 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.</p>
# </div>
# <!-- [D] 구형: .com_list.com_list_headline, 이시각주요뉴스:.newsnow, 헤드라인뉴스:.hdline_news -->
# <div class="hdline_news">
# <div class="hdline_flick">
# <div class="hdline_flick_item" style="display:block">
# <a class="lnk_hdline_main_article nclicks('mai.image', '880000D1_000000000000000003182379', 'airsGParam', '0', 'news_global_v2.0', 'RVIJA3fg4LTj8o63')" href="/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=081&amp;aid=0003182379">
# <img alt="이건희 회장, 평생 일군 재산 60% 이상 세상에 내놓고 떠났다" height="190" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_300x190.png';" src="https://imgnews.pstatic.net/image/081/2021/04/28/0003182379_001_20210428111701853.jpg?type=nf300_190" width="300"/>
# <div class="hdline_flick_mask">
# <p class="hdline_flick_tit">이건희 회장, 평생 일군 재산 60% 이상 세상에 …</p>
# </div>
# </a>
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '880000D1_000000000000000003182379', 'airsGParam', '0', 'news_global_v2.0', 'RVIJA3fg4LTj8o63')" href="/main/clusterArticles.nhn?id=c_202104281110_00000015&amp;mode=LSD&amp;mid=shm&amp;oid=081&amp;aid=0003182379">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">84</span>
# </a>
# </div>
# <div class="hdline_flick_item" style="display:none">
# <a class="lnk_hdline_main_article nclicks('mai.image', '880000D8_000000000000000012359034', 'airsGParam', '0', 'news_global_v2.0', 'RVIJA3fg4LTj8o63')" href="/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0012359034">
# <img alt="'윤석열과 구원' 김용판 " height="190" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_300x190.png';" src="https://imgnews.pstatic.net/image/001/2021/04/28/PYH2021042806660001300_P4_20210428113711809.jpg?type=nf300_190" width="300" 尹,="" 거쳐야""="" 누명씌워…고해성사=""/>
# <div class="hdline_flick_mask">
# <p class="hdline_flick_tit">'윤석열과 구원' 김용판 "尹, 누명씌워…고해성…</p>
# </div>
# </a>
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '880000D8_000000000000000012359034', 'airsGParam', '0', 'news_global_v2.0', 'RVIJA3fg4LTj8o63')" href="/main/clusterArticles.nhn?id=c_202104281030_00000053&amp;mode=LSD&amp;mid=shm&amp;oid=001&amp;aid=0012359034">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">23</span>
# </a>
# </div>
# <div class="hdline_flick_navi">
# <button class="flick_btn_prev nclicks(mai.prev)" disabled="disabled" onclick="prevRecommend(); " type="button"><span class="blind">이전기사</span></button><button class="flick_btn_next nclicks(mai.next)" onclick="nextRecommend(); " type="button"><span class="blind">다음기사</span></button>
# </div> <!--[D] 버튼 비활성: disabled 속성 추가 -->
# </div>
# <ul class="hdline_article_list">
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '880000AF_000000000000000001581133', 'airsGParam', '0', 'news_global_v2.0', 'RVIJA3fg4LTj8o63')" href="/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001581133">
#                                         장병 백신 접종, 92개 군 기관서 시작...다음 날까지 전투휴무·청원휴가
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '880000AF_000000000000000001581133', 'airsGParam', '0', 'news_global_v2.0', 'RVIJA3fg4LTj8o63')" href="/main/clusterArticles.nhn?id=c_202104261440_00000050&amp;mode=LSD&amp;mid=shm&amp;oid=052&amp;aid=0001581133">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">44</span>
# </a>
# </div>
# </li>
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '08138263_000000000000000005317989', 'airsGParam', '0', 'news_global_v2.0', 'RVIJA3fg4LTj8o63')" href="/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=421&amp;aid=0005317989">
#                                         종합소득세 납부 5월31일까지…대면 운영없이 온라인으로만
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '08138263_000000000000000005317989', 'airsGParam', '0', 'news_global_v2.0', 'RVIJA3fg4LTj8o63')" href="/main/clusterArticles.nhn?id=c_202104281210_00000023&amp;mode=LSD&amp;mid=shm&amp;oid=421&amp;aid=0005317989">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">18</span>
# </a>
# </div>
# </li>
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '88000114_000000000000000011034080', 'airsGParam', '0', 'news_global_v2.0', 'RVIJA3fg4LTj8o63')" href="/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=056&amp;aid=0011034080">
#                                         정부 “백신 접종 완료자, 다음달 5일부터 자가격리 등 완화”
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '88000114_000000000000000011034080', 'airsGParam', '0', 'news_global_v2.0', 'RVIJA3fg4LTj8o63')" href="/main/clusterArticles.nhn?id=c_202104271440_00000009&amp;mode=LSD&amp;mid=shm&amp;oid=056&amp;aid=0011034080">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">38</span>
# </a>
# </div>
# </li>
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '880000D8_000000000000000012358559', 'airsGParam', '0', 'news_global_v2.0', 'RVIJA3fg4LTj8o63')" href="/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=001&amp;aid=0012358559">
#                                         시민단체들 "吳 약속 뒤집어…광화문광장 재검토해야"
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '880000D8_000000000000000012358559', 'airsGParam', '0', 'news_global_v2.0', 'RVIJA3fg4LTj8o63')" href="/main/clusterArticles.nhn?id=c_202104271040_00000011&amp;mode=LSD&amp;mid=shm&amp;oid=001&amp;aid=0012358559">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">74</span>
# </a>
# </div>
# </li>
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '880000D8_000000000000000012359013', 'airsGParam', '0', 'news_global_v2.0', 'RVIJA3fg4LTj8o63')" href="/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=001&amp;aid=0012359013">
#                                         SKIET 청약 1시간 만에 증거금 6.2조…SK바사 수준 넘어
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '880000D8_000000000000000012359013', 'airsGParam', '0', 'news_global_v2.0', 'RVIJA3fg4LTj8o63')" href="/main/clusterArticles.nhn?id=c_202104261710_00000313&amp;mode=LSD&amp;mid=shm&amp;oid=001&amp;aid=0012359013">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">49</span>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="btn_move">
# <!-- [D] .down_off 또는 .up_off 추가시 '<span class="blind">불가능</span>' 추가 -->
# <span class="move" title="이동">이동</span> <a class="up nclicks(mai.up)" href="#SLELq" title="위로">위로</a> <a class="down_off nclicks(mai.down)" href="#SLELq" title="아래로">아래로<span class="blind">불가능</span></a>
# </div>
# </div>
# <script type="text/javascript">
#             var recommendIdx = 0;
#             var recommendLength = $("#today_main_news .hdline_flick_item").length;
#
#             function prevRecommend() {
#                 if ( recommendIdx-1 >= 0) {
#                     recommendIdx -= 1;
#                 }
#
#                 recBtnDisabled();
#
#                 $("#today_main_news .hdline_flick_item").css("display", "none");
#                 $("#today_main_news .hdline_flick_item").eq(recommendIdx).css("display", "block");
#             }
#
#             function nextRecommend() {
#                 if ( recommendIdx+1 < recommendLength) {
#                     recommendIdx += 1;
#                 }
#
#                 recBtnDisabled();
#
#                 $("#today_main_news .hdline_flick_item").css("display", "none");
#                 $("#today_main_news .hdline_flick_item").eq(recommendIdx).css("display", "block");
#             }
#
#             function recBtnDisabled() {
#                 $("#today_main_news .flick_btn_prev").removeAttr("disabled");
#                 $("#today_main_news .flick_btn_next").removeAttr("disabled");
#
#                 if ( recommendIdx === 0 ) {
#                     $("#today_main_news .flick_btn_prev").attr("disabled", "disabled");
#                 }
#                 if ( recommendIdx === recommendLength -1 ) {
#                     $("#today_main_news .flick_btn_next").attr("disabled", "disabled");
#                 }
#             }
#         </script>
# <div class="main_component droppable" id="section_politics">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(pol.title)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h4>
# <span class="tit_sub">
# <a class="nclicks(pol.common)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">일반</a><span class="bar"></span>
# <a class="nclicks(pol.party)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당</a><span class="bar"></span>
# <a class="nclicks(pol.chung)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">청와대</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','880000ED_000000000000000003610858', 'airsGParam', '0', 'news_sec_v2.0', '1L2VdvXhlVA6rrW1')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003610858">
# <img alt="與 김용민 “문자 폭탄? 적극적 의사 표시는 권장해야”" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/023/2021/04/28/3610858.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','880000ED_000000000000000003610858', 'airsGParam', '0', 'news_sec_v2.0', '1L2VdvXhlVA6rrW1')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003610858">與 김용민 “문자 폭탄? 적극적 의사 표시는 권장해야”</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','880000ED_000000000000000003610858', 'airsGParam', '0', 'news_sec_v2.0', '1L2VdvXhlVA6rrW1')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=030&amp;aid=0002941768">
# <strong>암호화폐, 정부여당 고심속, 특위 구성 들어간 야당</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">전자신문</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000ED_000000000000000003610858', 'airsGParam', '0', 'news_sec_v2.0', '1L2VdvXhlVA6rrW1')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=028&amp;aid=0002542292">
# <strong>주호영 “손실보상제 통과 못해 아쉬워…합당 윤곽 다 드러나”</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">한겨레</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000ED_000000000000000003610858', 'airsGParam', '0', 'news_sec_v2.0', '1L2VdvXhlVA6rrW1')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=011&amp;aid=0003903282">
# <strong>김남국, '한중문화타운' 무산에 이준석 직격 "왜곡된 선동, 청년 일자리 걷어차"</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">서울경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000ED_000000000000000003610858', 'airsGParam', '0', 'news_sec_v2.0', '1L2VdvXhlVA6rrW1')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=422&amp;aid=0000482649">
# <strong>검찰총장 후보 추천위원회 D-1…최종 후보 관심</strong>
# </a>
# <strong class="r_ico r_vod_txt">동영상기사</strong>
# <span class="writing">연합뉴스TV</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000ED_000000000000000003610858', 'airsGParam', '0', 'news_sec_v2.0', '1L2VdvXhlVA6rrW1')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003097374">
# <strong>오세훈 “아무런 보고 받지 않아…오히려 TBS가 궁금해 여겨”</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">중앙일보</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(soc.move)" title="이동">이동</span>
# <a class="up nclicks(soc.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(soc.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_economy">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(eco.title)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=101">경제</a></h4>
# <span class="tit_sub">
# <a class="nclicks(eco.common)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=263">일반</a><span class="bar"></span>
# <a class="nclicks(eco.finance)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=259">금융</a><span class="bar"></span>
# <a class="nclicks(eco.domestic)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=310">생활경제</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','88213rx9_000000000000000000000710', 'airsGParam', '0', 'news_sec_v2.0', '8y0o4R2NKLmbtWnT')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=648&amp;aid=0000000710">
# <img alt="한국 기업 편입 늘리는 클린ETF…수혜 종목은" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/648/2021/04/28/710.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','88213rx9_000000000000000000000710', 'airsGParam', '0', 'news_sec_v2.0', '8y0o4R2NKLmbtWnT')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=648&amp;aid=0000000710">한국 기업 편입 늘리는 클린ETF…수혜 종목은</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','88213rx9_000000000000000000000710', 'airsGParam', '0', 'news_sec_v2.0', '8y0o4R2NKLmbtWnT')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=009&amp;aid=0004786166">
# <strong>故 이건희 회장 상속세 12조원 이상 납부…세계 최고액 [종합]</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">매일경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88213rx9_000000000000000000000710', 'airsGParam', '0', 'news_sec_v2.0', '8y0o4R2NKLmbtWnT')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=014&amp;aid=0004629176">
# <strong>'한화 포레나 포항' 포항 북구 역대 최다 청약자 몰려</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">파이낸셜뉴스</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88213rx9_000000000000000000000710', 'airsGParam', '0', 'news_sec_v2.0', '8y0o4R2NKLmbtWnT')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=008&amp;aid=0004579481">
# <strong>'전기차 배터리' 자체개발 나선 포드…"SK이노 협업 당분간 지속"</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">머니투데이</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88213rx9_000000000000000000000710', 'airsGParam', '0', 'news_sec_v2.0', '8y0o4R2NKLmbtWnT')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=025&amp;aid=0003097375">
# <strong>2시간만에 7조 몰린 SKIET…청약 광풍, SK바사 넘어서나</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">중앙일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88213rx9_000000000000000000000710', 'airsGParam', '0', 'news_sec_v2.0', '8y0o4R2NKLmbtWnT')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=003&amp;aid=0010471182">
# <strong>이건희 회장 유언 뭐였길래…사회환원 주요 어록</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">뉴시스</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(pol.move)" title="이동">이동</span>
# <a class="up nclicks(pol.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(pol.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_society">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(soc.title)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=102">사회</a></h4>
# <span class="tit_sub">
# <a class="nclicks(soc.common)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=257">일반</a><span class="bar"></span>
# <a class="nclicks(soc.edu)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=250">교육</a><span class="bar"></span>
# <a class="nclicks(soc.labor)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=251">노동</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','880000E7_000000000000000004914343', 'airsGParam', '0', 'news_sec_v2.0', 'Bq80KElXDWXUy2LN')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=018&amp;aid=0004914343">
# <img alt="'내가 누군지 아냐' 장제원 아들 노엘, '폭행 혐의' 검찰 송치" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/018/2021/04/28/4914343.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','880000E7_000000000000000004914343', 'airsGParam', '0', 'news_sec_v2.0', 'Bq80KElXDWXUy2LN')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=018&amp;aid=0004914343">'내가 누군지 아냐' 장제원 아들 노엘, '폭행 혐의' 검찰 송치</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','880000E7_000000000000000004914343', 'airsGParam', '0', 'news_sec_v2.0', 'Bq80KElXDWXUy2LN')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=088&amp;aid=0000700407">
# <strong>"조국 딸 병원서 만날까 두렵다" 발언한 김재섭, 경찰 수사 착수</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">매일신문</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000E7_000000000000000004914343', 'airsGParam', '0', 'news_sec_v2.0', 'Bq80KElXDWXUy2LN')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=025&amp;aid=0003097380">
# <strong>"손수레 힘들다" 호소문 붙였다고···택배기사 고발한 아파트</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">중앙일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000E7_000000000000000004914343', 'airsGParam', '0', 'news_sec_v2.0', 'Bq80KElXDWXUy2LN')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=025&amp;aid=0003097379">
# <strong>'불사조' 이상직 의원 구속…9개월간 무슨 일이</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">중앙일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000E7_000000000000000004914343', 'airsGParam', '0', 'news_sec_v2.0', 'Bq80KElXDWXUy2LN')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=023&amp;aid=0003610859">
# <strong>산나물 욕심에… 군부대 침입 후 도주한 50대 붙잡혀</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">조선일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000E7_000000000000000004914343', 'airsGParam', '0', 'news_sec_v2.0', 'Bq80KElXDWXUy2LN')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=421&amp;aid=0005318233">
# <strong>"이제는 천국에서 편히 쉬시길"…종일 故 정진석 추기경 추모 행렬(종합)</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">뉴스1</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(eco.move)" title="이동">이동</span>
# <a class="up nclicks(eco.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(eco.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_life">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(lif.title)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=103">생활/문화</a></h4>
# <span class="tit_sub">
# <a class="nclicks(lif.health)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=241">건강</a><span class="bar"></span>
# <a class="nclicks(lif.travel)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=237">여행</a><span class="bar"></span>
# <a class="nclicks(lif.car)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=239">자동차</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','8800006E_000000000000000000015392', 'airsGParam', '0', 'news_sec_v2.0', 'DjnEYq2xMWGZCEua')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=145&amp;aid=0000015392">
# <img alt="극심한 어깨 통증 주범 '석회성건염', 수술이 답일까?" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/145/2021/04/28/15392.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# ...
# </ul>
# </div>, <div class="today_finance">
# <h5 class="blind">코스피,코스닥 지수</h5>
# <ul>
# <li> <a class="b nclicks(rig.today)" href="https://finance.naver.com/sise/sise_index.nhn?code=KOSPI" target="_blank"> <strong>코스피</strong>
# <div class="num">
#        3,188.54
#       </div>
# <div class="num dn">
# <i>하락</i>26.88
#       </div> </a> </li>
# <li> <a class="b nclicks(rig.today)" href="https://finance.naver.com/sise/sise_index.nhn?code=KOSDAQ" target="_blank"> <strong>코스닥</strong>
# <div class="num">
#        1,003.48
#       </div>
# <div class="num dn">
# <i>하락</i>17.53
#       </div> </a> </li>
# </ul>
# </div>, <div class="num">
#        3,188.54
#       </div>, <div class="num dn">
# <i>하락</i>26.88
#       </div>, <div class="num">
#        1,003.48
#       </div>, <div class="num dn">
# <i>하락</i>17.53
#       </div>, <div class="section">
# <h4>만평</h4>
# <div class="img_rolling v1" id="rightOpinionCartoonPhoto4_1078954">
# <div class="_1" style="display: none;">
# <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#277_0004893158"> <img alt="[오성수의 툰] 방탄검사단" height="180" src="https://mimgnews.pstatic.net/image/origin/277/2021/04/28/4893158.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">아시아경제</span> </span> </span> </img></a>
# </div>
# <div class="_2" style="display: none;">
# <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#032_0003071440"> <img alt="2021년 4월 28일 [장도리]" height="180" src="https://mimgnews.pstatic.net/image/origin/032/2021/04/27/3071440.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">경향신문</span> </span> </span> </img></a>
# </div>
# <div class="_3" style="display: none;">
# <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#081_0003182201"> <img alt="[만평] 조기영의 세상터치 2021년 4월 28일" height="180" src="https://mimgnews.pstatic.net/image/origin/081/2021/04/27/3182201.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">서울신문</span> </span> </span> </img></a>
# </div>
# <div class="_4" style="display: none;">
# <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#005_0001434458"> <img alt="[국민만평-서민호 화백] 2021년 4월 28일" height="180" src="https://mimgnews.pstatic.net/image/origin/005/2021/04/27/1434458.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">국민일보</span> </span> </span> </img></a>
# </div>
# <ul style="display: none;">
# </ul>
# <ul class="_temp" style="display: none;">
#    shuffle 이전 위치
#    <li class="_1"> <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#277_0004893158"> <img alt="[오성수의 툰] 방탄검사단" height="45" src="https://mimgnews.pstatic.net/image/origin/277/2021/04/28/4893158.jpg?type=nf74_45" width="74"> <span class="trans_border2"></span> </img></a> </li>
# <li class="_2"> <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#032_0003071440"> <img alt="2021년 4월 28일 [장도리]" height="45" src="https://mimgnews.pstatic.net/image/origin/032/2021/04/27/3071440.jpg?type=nf73_45" width="73"> <span class="trans_border2"></span> </img></a> </li>
# <li class="_3"> <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#081_0003182201"> <img alt="[만평] 조기영의 세상터치 2021년 4월 28일" height="45" src="https://mimgnews.pstatic.net/image/origin/081/2021/04/27/3182201.jpg?type=nf73_45" width="73"> <span class="trans_border2"></span> </img></a> </li>
# <li class="_4"> <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#005_0001434458"> <img alt="[국민만평-서민호 화백] 2021년 4월 28일" height="45" src="https://mimgnews.pstatic.net/image/origin/005/2021/04/27/1434458.jpg?type=nf74_45" width="74"> <span class="trans_border2"></span> </img></a> </li>
# </ul>
# </div>
# <a class="more_link" href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307" title="만평 더보기"><span class="blind">만평</span>더보기</a>
# </div>, <div class="img_rolling v1" id="rightOpinionCartoonPhoto4_1078954">
# <div class="_1" style="display: none;">
# <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#277_0004893158"> <img alt="[오성수의 툰] 방탄검사단" height="180" src="https://mimgnews.pstatic.net/image/origin/277/2021/04/28/4893158.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">아시아경제</span> </span> </span> </img></a>
# </div>
# <div class="_2" style="display: none;">
# <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#032_0003071440"> <img alt="2021년 4월 28일 [장도리]" height="180" src="https://mimgnews.pstatic.net/image/origin/032/2021/04/27/3071440.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">경향신문</span> </span> </span> </img></a>
# </div>
# <div class="_3" style="display: none;">
# <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#081_0003182201"> <img alt="[만평] 조기영의 세상터치 2021년 4월 28일" height="180" src="https://mimgnews.pstatic.net/image/origin/081/2021/04/27/3182201.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">서울신문</span> </span> </span> </img></a>
# </div>
# <div class="_4" style="display: none;">
# <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#005_0001434458"> <img alt="[국민만평-서민호 화백] 2021년 4월 28일" height="180" src="https://mimgnews.pstatic.net/image/origin/005/2021/04/27/1434458.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">국민일보</span> </span> </span> </img></a>
# </div>
# <ul style="display: none;">
# </ul>
# <ul class="_temp" style="display: none;">
#    shuffle 이전 위치
#    <li class="_1"> <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#277_0004893158"> <img alt="[오성수의 툰] 방탄검사단" height="45" src="https://mimgnews.pstatic.net/image/origin/277/2021/04/28/4893158.jpg?type=nf74_45" width="74"> <span class="trans_border2"></span> </img></a> </li>
# <li class="_2"> <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#032_0003071440"> <img alt="2021년 4월 28일 [장도리]" height="45" src="https://mimgnews.pstatic.net/image/origin/032/2021/04/27/3071440.jpg?type=nf73_45" width="73"> <span class="trans_border2"></span> </img></a> </li>
# <li class="_3"> <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#081_0003182201"> <img alt="[만평] 조기영의 세상터치 2021년 4월 28일" height="45" src="https://mimgnews.pstatic.net/image/origin/081/2021/04/27/3182201.jpg?type=nf73_45" width="73"> <span class="trans_border2"></span> </img></a> </li>
# <li class="_4"> <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#005_0001434458"> <img alt="[국민만평-서민호 화백] 2021년 4월 28일" height="45" src="https://mimgnews.pstatic.net/image/origin/005/2021/04/27/1434458.jpg?type=nf74_45" width="74"> <span class="trans_border2"></span> </img></a> </li>
# </ul>
# </div>, <div class="_1" style="display: none;">
# <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#277_0004893158"> <img alt="[오성수의 툰] 방탄검사단" height="180" src="https://mimgnews.pstatic.net/image/origin/277/2021/04/28/4893158.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">아시아경제</span> </span> </span> </img></a>
# </div>, <div class="_2" style="display: none;">
# <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#032_0003071440"> <img alt="2021년 4월 28일 [장도리]" height="180" src="https://mimgnews.pstatic.net/image/origin/032/2021/04/27/3071440.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">경향신문</span> </span> </span> </img></a>
# </div>, <div class="_3" style="display: none;">
# <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#081_0003182201"> <img alt="[만평] 조기영의 세상터치 2021년 4월 28일" height="180" src="https://mimgnews.pstatic.net/image/origin/081/2021/04/27/3182201.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">서울신문</span> </span> </span> </img></a>
# </div>, <div class="_4" style="display: none;">
# <a href="/main/cartoongallery/index.nhn?mid=pho&amp;sid2=307#005_0001434458"> <img alt="[국민만평-서민호 화백] 2021년 4월 28일" height="180" src="https://mimgnews.pstatic.net/image/origin/005/2021/04/27/1434458.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">국민일보</span> </span> </span> </img></a>
# </div>, <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.nhn"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.nhn?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.nhn?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&amp;sid1=100&amp;cid=909906&amp;decorator=ombudsman&amp;confirm=true"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.nhn"><span class="blind">서비스 안내</span>더보기</a>
# </div>, <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.nhn?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/182956245_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
# </div>
# </div>, <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.nhn?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/182956245_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
# </div>, <div class="da" id="rightDoubleDA" style="display: none"></div>, <div class="rightBottomDouble" style="margin-top:36px;"><div data-dom-type="doubleplay_bottom" id="doubleHome300250" name="doubleHome300250" title="더블플레이하단광고"></div></div>, <div data-dom-type="doubleplay_bottom" id="doubleHome300250" name="doubleHome300250" title="더블플레이하단광고"></div>, <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# <div class="index_myscrap">
# <a class="spr nclicks(fot.scrap)" href="/main/scrap/index.nhn">마이스크랩</a>
# </div>
# </div>
# </div>, <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# <div class="index_myscrap">
# <a class="spr nclicks(fot.scrap)" href="/main/scrap/index.nhn">마이스크랩</a>
# </div>
# </div>, <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>, <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>, <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>, <div class="index_content is_hidden" id="index.press.area"></div>, <div class="index_content02 is_hidden" id="index.category.area"></div>, <div class="index_myscrap">
# <a class="spr nclicks(fot.scrap)" href="/main/scrap/index.nhn">마이스크랩</a>
# </div>, <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.nhn">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.nhn?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>]
