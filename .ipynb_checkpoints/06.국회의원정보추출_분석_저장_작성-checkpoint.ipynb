# %%
import requests
from bs4 import BeautifulSoup
import re

url = 'https://www.assembly.go.kr/assm/memact/congressman/memCond/memCondListAjax.do'
req_param = {
    "currentPage":1,
    "rowPerPage":500
}

res = requests.get(url, params=req_param)
print(res.status_code)
if res.ok:
    html = res.text
    soup = BeautifulSoup(html,'html.parser')
    
    print(len(soup.select('div.memberna_list dl dt a')))
    member_list = []
    for atag in soup.select('div.memberna_list dl dt a'):
        href_value = atag['href']
        name = atag.text
        matched = re.search(r'(\d+)', href_value)
        print(name, href_value)
# Out:
# 200
# 300
# 강기윤 javascript:jsMemPop('9771230')
# 강대식 javascript:jsMemPop('9771142')
# 강득구 javascript:jsMemPop('9771174')
# 강민국 javascript:jsMemPop('9771233')
# 강민정 javascript:jsMemPop('9771283')
# 강병원 javascript:jsMemPop('9770933')
# 강선우 javascript:jsMemPop('9771116')
# 강은미 javascript:jsMemPop('9771276')
# 강준현 javascript:jsMemPop('9771168')
# 강훈식 javascript:jsMemPop('9771007')
# 고민정 javascript:jsMemPop('9771109')
# 고영인 javascript:jsMemPop('9771180')
# 고용진 javascript:jsMemPop('9770931')
# 곽상도 javascript:jsMemPop('9770956')
# 구자근 javascript:jsMemPop('9771224')
# 권명호 javascript:jsMemPop('9771165')
# 권성동 javascript:jsMemPop('9770679')
# 권영세 javascript:jsMemPop('9771108')
# 권은희 javascript:jsMemPop('9770977')
# 권인숙 javascript:jsMemPop('9771259')
# 권칠승 javascript:jsMemPop('9770998')
# 기동민 javascript:jsMemPop('9770927')
# 김경만 javascript:jsMemPop('9771258')
# 김경협 javascript:jsMemPop('9770712')
# 김교흥 javascript:jsMemPop('9771152')
# 김기현 javascript:jsMemPop('9771164')
# 김남국 javascript:jsMemPop('9771181')
# 김도읍 javascript:jsMemPop('9770719')
# 김두관 javascript:jsMemPop('9770997')
# 김미애 javascript:jsMemPop('9771136')
# 김민기 javascript:jsMemPop('9770723')
# 김민석 javascript:jsMemPop('9771120')
# 김민철 javascript:jsMemPop('9771173')
# 김병기 javascript:jsMemPop('9770941')
# 김병욱 javascript:jsMemPop('9770984')
# 김병욱 javascript:jsMemPop('9771285')
# 김병주 javascript:jsMemPop('9771268')
# 김상훈 javascript:jsMemPop('9770725')
# 김상희 javascript:jsMemPop('9770527')
# 김석기 javascript:jsMemPop('9771024')
# 김선교 javascript:jsMemPop('9771195')
# 김성원 javascript:jsMemPop('9770985')
# 김성주 javascript:jsMemPop('9771208')
# 김성환 javascript:jsMemPop('9771089')
# 김수흥 javascript:jsMemPop('9771210')
# 김승남 javascript:jsMemPop('9771220')
# 김승수 javascript:jsMemPop('9771144')
# 김승원 javascript:jsMemPop('9771169')
# 김영배 javascript:jsMemPop('9771111')
# 김영식 javascript:jsMemPop('9771225')
# 김영주 javascript:jsMemPop('9770975')
# 김영진 javascript:jsMemPop('9770981')
# 김영호 javascript:jsMemPop('9770934')
# 김예지 javascript:jsMemPop('9771249')
# 김용민 javascript:jsMemPop('9771186')
# 김용판 javascript:jsMemPop('9771147')
# 김웅 javascript:jsMemPop('9771127')
# 김원이 javascript:jsMemPop('9771214')
# 김윤덕 javascript:jsMemPop('9771206')
# 김은혜 javascript:jsMemPop('9771171')
# 김의겸 javascript:jsMemPop('9771288')
# 김정재 javascript:jsMemPop('9771023')
# 김정호 javascript:jsMemPop('9771090')
# 김종민 javascript:jsMemPop('9771009')
# 김주영 javascript:jsMemPop('9771192')
# 김진표 javascript:jsMemPop('9770982')
# 김철민 javascript:jsMemPop('9770986')
# 김태년 javascript:jsMemPop('9770741')
# 김태호 javascript:jsMemPop('9771237')
# 김태흠 javascript:jsMemPop('9770742')
# 김한정 javascript:jsMemPop('9770991')
# 김형동 javascript:jsMemPop('9771223')
# 김홍걸 javascript:jsMemPop('9771270')
# 김회재 javascript:jsMemPop('9771216')
# 김희곤 javascript:jsMemPop('9771134')
# 김희국 javascript:jsMemPop('9771228')
# 남인순 javascript:jsMemPop('9770752')
# 노웅래 javascript:jsMemPop('9770753')
# 도종환 javascript:jsMemPop('9770755')
# 류성걸 javascript:jsMemPop('9771141')
# 류호정 javascript:jsMemPop('9771274')
# 맹성규 javascript:jsMemPop('9771091')
# 문정복 javascript:jsMemPop('9771187')
# 문진석 javascript:jsMemPop('9771204')
# 민병덕 javascript:jsMemPop('9771175')
# 민형배 javascript:jsMemPop('9771159')
# 민홍철 javascript:jsMemPop('9770764')
# 박광온 javascript:jsMemPop('9770911')
# 박대수 javascript:jsMemPop('9771248')
# 박대출 javascript:jsMemPop('9770767')
# 박덕흠 javascript:jsMemPop('9770768')
# 박범계 javascript:jsMemPop('9770770')
# 박병석 javascript:jsMemPop('9770090')
# 박상혁 javascript:jsMemPop('9771193')
# 박성민 javascript:jsMemPop('9771163')
# 박성준 javascript:jsMemPop('9771107')
# 박성중 javascript:jsMemPop('9770944')
# 박수영 javascript:jsMemPop('9771135')
# 박영순 javascript:jsMemPop('9771162')
# 박완수 javascript:jsMemPop('9771030')
# 박완주 javascript:jsMemPop('9770774')
# 박용진 javascript:jsMemPop('9770929')
# 박재호 javascript:jsMemPop('9770950')
# 박정 javascript:jsMemPop('9770995')
# 박주민 javascript:jsMemPop('9770932')
# 박진 javascript:jsMemPop('9771125')
# 박찬대 javascript:jsMemPop('9770963')
# 박형수 javascript:jsMemPop('9771226')
# 박홍근 javascript:jsMemPop('9770779')
# 배준영 javascript:jsMemPop('9771148')
# 배진교 javascript:jsMemPop('9771277')
# 배현진 javascript:jsMemPop('9771128')
# 백종헌 javascript:jsMemPop('9771137')
# 백혜련 javascript:jsMemPop('9770980')
# 변재일 javascript:jsMemPop('9770356')
# 서동용 javascript:jsMemPop('9771218')
# 서범수 javascript:jsMemPop('9771166')
# 서병수 javascript:jsMemPop('9771133')
# 서삼석 javascript:jsMemPop('9771092')
# 서영교 javascript:jsMemPop('9770784')
# 서영석 javascript:jsMemPop('9771176')
# 서일준 javascript:jsMemPop('9771236')
# 서정숙 javascript:jsMemPop('9771254')
# 설훈 javascript:jsMemPop('9770786')
# 성일종 javascript:jsMemPop('9771008')
# 소병철 javascript:jsMemPop('9771217')
# 소병훈 javascript:jsMemPop('9770999')
# 송갑석 javascript:jsMemPop('9771093')
# 송기헌 javascript:jsMemPop('9771001')
# 송석준 javascript:jsMemPop('9770996')
# 송언석 javascript:jsMemPop('9771094')
# 송영길 javascript:jsMemPop('9770967')
# 송옥주 javascript:jsMemPop('9771058')
# 송재호 javascript:jsMemPop('9771238')
# 신동근 javascript:jsMemPop('9770968')
# 신영대 javascript:jsMemPop('9771209')
# 신원식 javascript:jsMemPop('9771246')
# 신정훈 javascript:jsMemPop('9771219')
# 신현영 javascript:jsMemPop('9771257')
# 심상정 javascript:jsMemPop('9770869')
# 안규백 javascript:jsMemPop('9770587')
# 안민석 javascript:jsMemPop('9770372')
# 안병길 javascript:jsMemPop('9771132')
# 안호영 javascript:jsMemPop('9771017')
# 양경숙 javascript:jsMemPop('9771273')
# 양금희 javascript:jsMemPop('9771143')
# 양기대 javascript:jsMemPop('9771178')
# 양이원영 javascript:jsMemPop('9771287')
# 양정숙 javascript:jsMemPop('9771271')
# 양향자 javascript:jsMemPop('9771155')
# 어기구 javascript:jsMemPop('9771010')
# 엄태영 javascript:jsMemPop('9771202')
# 오기형 javascript:jsMemPop('9771113')
# 오영환 javascript:jsMemPop('9771172')
# 오영훈 javascript:jsMemPop('9771037')
# 용혜인 javascript:jsMemPop('9771261')
# 우상호 javascript:jsMemPop('9770871')
# 우원식 javascript:jsMemPop('9770872')
# 위성곤 javascript:jsMemPop('9771038')
# 유경준 javascript:jsMemPop('9771126')
# 유기홍 javascript:jsMemPop('9771121')
# 유동수 javascript:jsMemPop('9770966')
# 유상범 javascript:jsMemPop('9771199')
# 유의동 javascript:jsMemPop('9770912')
# 유정주 javascript:jsMemPop('9771266')
# 윤건영 javascript:jsMemPop('9771118')
# 윤관석 javascript:jsMemPop('9770808')
# 윤두현 javascript:jsMemPop('9771227')
# 윤미향 javascript:jsMemPop('9771263')
# 윤상현 javascript:jsMemPop('9770598')
# 윤영덕 javascript:jsMemPop('9771153')
# 윤영석 javascript:jsMemPop('9770811')
# 윤영찬 javascript:jsMemPop('9771170')
# 윤재갑 javascript:jsMemPop('9771221')
# 윤재옥 javascript:jsMemPop('9770812')
# 윤주경 javascript:jsMemPop('9771239')
# 윤준병 javascript:jsMemPop('9771212')
# 윤창현 javascript:jsMemPop('9771240')
# 윤한홍 javascript:jsMemPop('9771032')
# 윤호중 javascript:jsMemPop('9770876')
# 윤후덕 javascript:jsMemPop('9770813')
# 윤희숙 javascript:jsMemPop('9771123')
# 이개호 javascript:jsMemPop('9770905')
# 이광재 javascript:jsMemPop('9771198')
# 이규민 javascript:jsMemPop('9771191')
# 이낙연 javascript:jsMemPop('9771106')
# 이달곤 javascript:jsMemPop('9771232')
# 이동주 javascript:jsMemPop('9771260')
# 이만희 javascript:jsMemPop('9771028')
# 이명수 javascript:jsMemPop('9770602')
# 이병훈 javascript:jsMemPop('9771154')
# 이상민 javascript:jsMemPop('9770414')
# 이상직 javascript:jsMemPop('9771207')
# 이상헌 javascript:jsMemPop('9771098')
# 이성만 javascript:jsMemPop('9771151')
# 이소영 javascript:jsMemPop('9771185')
# 이수진 javascript:jsMemPop('9771284')
# 이수진 javascript:jsMemPop('9771269')
# 이양수 javascript:jsMemPop('9771003')
# 이영 javascript:jsMemPop('9771251')
# 이용 javascript:jsMemPop('9771255')
# 이용빈 javascript:jsMemPop('9771158')
# 이용선 javascript:jsMemPop('9771115')
# 이용우 javascript:jsMemPop('9771184')
# 이용호 javascript:jsMemPop('9771015')
# 이원욱 javascript:jsMemPop('9770826')
# 이원택 javascript:jsMemPop('9771213')
# 이은주 javascript:jsMemPop('9771278')
# 이인영 javascript:jsMemPop('9770878')
# 이장섭 javascript:jsMemPop('9771201')
# 이재정 javascript:jsMemPop('9771060')
# 이정문 javascript:jsMemPop('9771205')
# 이종배 javascript:jsMemPop('9770914')
# 이종성 javascript:jsMemPop('9771242')
# 이주환 javascript:jsMemPop('9771138')
# 이채익 javascript:jsMemPop('9770835')
# 이철규 javascript:jsMemPop('9771002')
# 이탄희 javascript:jsMemPop('9771190')
# 이태규 javascript:jsMemPop('9771280')
# 이학영 javascript:jsMemPop('9770836')
# 이해식 javascript:jsMemPop('9771129')
# 이헌승 javascript:jsMemPop('9770837')
# 이형석 javascript:jsMemPop('9771157')
# 인재근 javascript:jsMemPop('9770839')
# 임오경 javascript:jsMemPop('9771177')
# 임이자 javascript:jsMemPop('9771041')
# 임종성 javascript:jsMemPop('9771000')
# 임호선 javascript:jsMemPop('9771203')
# 장경태 javascript:jsMemPop('9771110')
# 장제원 javascript:jsMemPop('9770954')
# 장철민 javascript:jsMemPop('9771160')
# 장혜영 javascript:jsMemPop('9771275')
# 전봉민 javascript:jsMemPop('9771139')
# 전용기 javascript:jsMemPop('9771272')
# 전재수 javascript:jsMemPop('9770951')
# 전주혜 javascript:jsMemPop('9771253')
# 전해철 javascript:jsMemPop('9770846')
# 전혜숙 javascript:jsMemPop('9770926')
# 정경희 javascript:jsMemPop('9771245')
# 정동만 javascript:jsMemPop('9771140')
# 정성호 javascript:jsMemPop('9770881')
# 정운천 javascript:jsMemPop('9771012')
# 정일영 javascript:jsMemPop('9771150')
# 정점식 javascript:jsMemPop('9771103')
# 정정순 javascript:jsMemPop('9771200')
# 정진석 javascript:jsMemPop('9771006')
# 정찬민 javascript:jsMemPop('9771189')
# 정청래 javascript:jsMemPop('9771114')
# 정춘숙 javascript:jsMemPop('9771068')
# 정태호 javascript:jsMemPop('9771122')
# 정필모 javascript:jsMemPop('9771264')
# 정희용 javascript:jsMemPop('9771229')
# 조경태 javascript:jsMemPop('9770450')
# 조명희 javascript:jsMemPop('9771247')
# 조수진 javascript:jsMemPop('9771243')
# 조승래 javascript:jsMemPop('9770973')
# 조오섭 javascript:jsMemPop('9771156')
# 조응천 javascript:jsMemPop('9770990')
# 조정식 javascript:jsMemPop('9770456')
# 조정훈 javascript:jsMemPop('9771262')
# 조태용 javascript:jsMemPop('9771244')
# 조해진 javascript:jsMemPop('9771235')
# 주철현 javascript:jsMemPop('9771215')
# 주호영 javascript:jsMemPop('9770883')
# 지성호 javascript:jsMemPop('9771250')
# 진선미 javascript:jsMemPop('9770852')
# 진성준 javascript:jsMemPop('9771117')
# 천준호 javascript:jsMemPop('9771112')
# 최강욱 javascript:jsMemPop('9771282')
# 최기상 javascript:jsMemPop('9771119')
# 최승재 javascript:jsMemPop('9771252')
# 최연숙 javascript:jsMemPop('9771279')
# 최인호 javascript:jsMemPop('9770952')
# 최종윤 javascript:jsMemPop('9771188')
# 최춘식 javascript:jsMemPop('9771194')
# 최형두 javascript:jsMemPop('9771231')
# 최혜영 javascript:jsMemPop('9771267')
# 추경호 javascript:jsMemPop('9770962')
# 태영호 javascript:jsMemPop('9771286')
# 하영제 javascript:jsMemPop('9771234')
# 하태경 javascript:jsMemPop('9770858')
# 한기호 javascript:jsMemPop('9771197')
# 한무경 javascript:jsMemPop('9771241')
# 한병도 javascript:jsMemPop('9771211')
# 한정애 javascript:jsMemPop('9770859')
# 한준호 javascript:jsMemPop('9771182')
# 허영 javascript:jsMemPop('9771196')
# 허은아 javascript:jsMemPop('9771256')
# 허종식 javascript:jsMemPop('9771149')
# 홍기원 javascript:jsMemPop('9771179')
# 홍문표 javascript:jsMemPop('9770886')
# 홍석준 javascript:jsMemPop('9771146')
# 홍성국 javascript:jsMemPop('9771167')
# 홍영표 javascript:jsMemPop('9770676')
# 홍익표 javascript:jsMemPop('9770864')
# 홍정민 javascript:jsMemPop('9771183')
# 홍준표 javascript:jsMemPop('9771145')
# 황보승희 javascript:jsMemPop('9771130')
# 황운하 javascript:jsMemPop('9771161')
# 황희 javascript:jsMemPop('9770936')
